# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch_geometric.loader import DataLoader
from pandas.tseries.holiday import USFederalHolidayCalendar
from sklearn.model_selection import train_test_split
import glob
import random

# Set random seed
seed = 391
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)

# Load adjacency matrix
adj_df = pd.read_csv('WECC_adjacent.csv', index_col=0)
edge_index = torch.tensor(np.array(np.where(adj_df.values == 1)), dtype=torch.long)

ba_names = list(adj_df.index)
ba_files_dict = {file.split('/')[-1].replace('_historical_data.csv', ''): file
                 for file in glob.glob('./WECC_compiled_historical_data/*.csv')}

# Reorder the files to match ba_names
# ba_files_order = [ba_files_dict[ba] for ba in ba_names]

x_train_node_features_list = []
y_train_node_features_list = []
x_val_node_features_list = []
y_val_node_features_list = []
x_test_node_features_list = []
y_test_node_features_list = []

min_y_train_list = []
max_y_train_list = []

dates_list = []
# ba_files = glob.glob('./WECC_compiled_historical_data/*.csv')

for ba_name in ba_names:
    file = ba_files_dict[ba_name]
    df = pd.read_csv(file)

    # Convert to datetime
    df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day', 'Hour']])
    
    # Remove rows with missing or infinite values
    features = ['Hour', 'Month', 'T2', 'Q2', 'WSPD', 'GLW', 'SWDOWN']
    target = 'Adjusted_Demand_MWh'
    df = df.replace([np.inf, -np.inf], np.nan)
    df = df.dropna(subset=features + [target])
    
    dates_list.append(set(df['Date'].unique()))

common_dates = set.intersection(*dates_list)
common_dates = sorted(list(common_dates))
print(f"Number of common dates: {len(common_dates)}")

for ba_name in ba_names:
    file = ba_files_dict[ba_name]
    df = pd.read_csv(file)

    # Convert to datetime
    df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day', 'Hour']])
    df['Date1'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

    # Add weekday feature
    df['Is_Weekday'] = df['Date1'].dt.weekday  # 0=Monday, 6=Sunday
    df['Weekday'] = (df['Is_Weekday'] < 5).astype(int)

    # Add holiday feature
    calendar = USFederalHolidayCalendar()
    holidays = calendar.holidays(start=df['Date1'].min(), end=df['Date1'].max())
    df['Holiday'] = df['Date1'].isin(holidays).astype(int)

    # Features and target
    features = ['Hour', 'Month', 'T2', 'Q2', 'WSPD', 'GLW', 'SWDOWN', 'Weekday', 'Holiday']
    target = 'Adjusted_Demand_MWh'

    # Keep only common dates
    df = df[df['Date'].isin(common_dates)]
    
    # Split by year
    data = df[df['Year'].isin([2016, 2017, 2018])]
    # val_data = df[df['Year'] == 2018]
    test_data = df[df['Year'] == 2019]

    # Prepare X and y
    X = data[features].values
    y = data[target].values.reshape(-1, 1)
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=391)

    # X_train = train_data[features].values
    # y_train = train_data[target].values.reshape(-1, 1)
    # X_val = val_data[features].values
    # y_val = val_data[target].values.reshape(-1, 1)
    X_test = test_data[features].values
    y_test = test_data[target].values.reshape(-1, 1)

    # Standardize
    min_x_train = np.min(X_train, axis=0)
    max_x_train = np.max(X_train, axis=0)
    min_y_train = np.min(y_train, axis=0)
    max_y_train = np.max(y_train, axis=0)

    min_y_train_list.append(min_y_train[0])  # save scalar
    max_y_train_list.append(max_y_train[0])

    x_train_norm = np.divide((X_train - min_x_train), (max_x_train - min_x_train))
    x_val_norm = np.divide((X_val - min_x_train), (max_x_train - min_x_train))
    x_test_norm = np.divide((X_test - min_x_train), (max_x_train - min_x_train))
    y_train_norm = np.divide((y_train - min_y_train), (max_y_train - min_y_train)).squeeze()
    y_val_norm = np.divide((y_val - min_y_train), (max_y_train - min_y_train)).squeeze()
    y_test_norm = np.divide((y_test - min_y_train), (max_y_train - min_y_train)).squeeze()

    x_train_node_features_list.append(x_train_norm)  # shape: (N_samples, num_features)
    y_train_node_features_list.append(y_train_norm)
    x_val_node_features_list.append(x_val_norm)  
    y_val_node_features_list.append(y_val_norm)
    x_test_node_features_list.append(x_test_norm)  
    y_test_node_features_list.append(y_test_norm)

# Stack into [samples, nodes, features]
x_np = np.stack(x_train_node_features_list, axis=1)
y_np = np.stack(y_train_node_features_list, axis=1)
x_val_np = np.stack(x_val_node_features_list, axis=1)
y_val_np = np.stack(y_val_node_features_list, axis=1)
x_test_np = np.stack(x_test_node_features_list, axis=1)
y_test_np = np.stack(y_test_node_features_list, axis=1)

min_y_train_array = np.array(min_y_train_list)  # shape: (nodes,)
max_y_train_array = np.array(max_y_train_list)  # shape: (nodes,)

# Tensor preparation
x_tensor = torch.tensor(x_np, dtype=torch.float)
y_tensor = torch.tensor(y_np, dtype=torch.float)
x_val_tensor = torch.tensor(x_val_np, dtype=torch.float)
y_val_tensor = torch.tensor(y_val_np, dtype=torch.float)
x_test_tensor = torch.tensor(x_test_np, dtype=torch.float)
y_test_tensor = torch.tensor(y_test_np, dtype=torch.float)
# Out:
# Number of common dates: 35138
# {'TPWR': './WECC_compiled_historical_data/TPWR_historical_data.csv', 'GCPD': './WECC_compiled_historical_data/GCPD_historical_data.csv', 'DOPD': './WECC_compiled_historical_data/DOPD_historical_data.csv', 'TIDC': './WECC_compiled_historical_data/TIDC_historical_data.csv', 'CISO': './WECC_compiled_historical_data/CISO_historical_data.csv', 'PSCO': './WECC_compiled_historical_data/PSCO_historical_data.csv', 'PNM': './WECC_compiled_historical_data/PNM_historical_data.csv', 'SCL': './WECC_compiled_historical_data/SCL_historical_data.csv', 'IPCO': './WECC_compiled_historical_data/IPCO_historical_data.csv', 'IID': './WECC_compiled_historical_data/IID_historical_data.csv', 'BPAT': './WECC_compiled_historical_data/BPAT_historical_data.csv', 'WACM': './WECC_compiled_historical_data/WACM_historical_data.csv', 'PSEI': './WECC_compiled_historical_data/PSEI_historical_data.csv', 'PACW': './WECC_compiled_historical_data/PACW_historical_data.csv', 'PGE': './WECC_compiled_historical_data/PGE_historical_data.csv', 'CHPD': './WECC_compiled_historical_data/CHPD_historical_data.csv', 'EPE': './WECC_compiled_historical_data/EPE_historical_data.csv', 'PACE': './WECC_compiled_historical_data/PACE_historical_data.csv', 'WAUW': './WECC_compiled_historical_data/WAUW_historical_data.csv', 'AVA': './WECC_compiled_historical_data/AVA_historical_data.csv', 'NEVP': './WECC_compiled_historical_data/NEVP_historical_data.csv', 'SRP': './WECC_compiled_historical_data/SRP_historical_data.csv', 'NWMT': './WECC_compiled_historical_data/NWMT_historical_data.csv', 'TEPC': './WECC_compiled_historical_data/TEPC_historical_data.csv', 'WALC': './WECC_compiled_historical_data/WALC_historical_data.csv', 'AZPS': './WECC_compiled_historical_data/AZPS_historical_data.csv', 'BANC': './WECC_compiled_historical_data/BANC_historical_data.csv', 'LDWP': './WECC_compiled_historical_data/LDWP_historical_data.csv'}
# [np.float64(748.0), np.float64(2028.0), np.float64(0.0), np.float64(3659.0), np.float64(27.0), np.float64(18068.0), np.float64(0.0), np.float64(0.0), np.float64(362.0), np.float64(0.0), np.float64(629.0), np.float64(0.0), np.float64(2835.0), np.float64(729.0), np.float64(0.0), np.float64(1.0), np.float64(1488.0), np.float64(1090.0), np.float64(0.0), np.float64(1861.0), np.float64(0.0), np.float64(0.0), np.float64(214.0), np.float64(0.0), np.float64(12.0), np.float64(0.0), np.float64(0.0), np.float64(5.0)]

# %% [markdown]
# Local GCN

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch_geometric.loader import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.metrics import r2_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === GCN Model Definition ===
class GCN(nn.Module):
    def __init__(self, in_channels, hidden_channels, mlp_hidden_channels1, mlp_hidden_channels2, dropout_rate=0):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.fc1 = nn.Linear(hidden_channels, mlp_hidden_channels1)
        self.fc2 = nn.Linear(mlp_hidden_channels1, mlp_hidden_channels2)
        self.fc3 = nn.Linear(mlp_hidden_channels2, 1)
        self.dropout = nn.Dropout(p=dropout_rate)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        return x.squeeze()

results = []

for ba_index, ba_name in enumerate(ba_names):
    print(f"Training for BA: {ba_name}")

    #Prepare data for current BA
    data_list, val_data_list, test_data_list = [], [], []

    for t in range(x_tensor.shape[0]):
        y_ba = y_tensor[t][ba_index].unsqueeze(0)
        mask = torch.zeros(x_tensor.shape[1], dtype=torch.bool)
        mask[ba_index] = True
        data_list.append(Data(x=x_tensor[t], edge_index=edge_index, y=y_ba, ba_mask=mask))

    for t in range(x_val_tensor.shape[0]):
        y_val_ba = y_val_tensor[t][ba_index].unsqueeze(0)
        mask = torch.zeros(x_val_tensor.shape[1], dtype=torch.bool)
        mask[ba_index] = True
        val_data_list.append(Data(x=x_val_tensor[t], edge_index=edge_index, y=y_val_ba, ba_mask=mask))

    for t in range(x_test_tensor.shape[0]):
        y_test_ba = y_test_tensor[t][ba_index].unsqueeze(0)
        mask = torch.zeros(x_test_tensor.shape[1], dtype=torch.bool)
        mask[ba_index] = True
        test_data_list.append(Data(x=x_test_tensor[t], edge_index=edge_index, y=y_test_ba, ba_mask=mask))

    train_loader = DataLoader(data_list, batch_size=256, shuffle=True)
    val_loader = DataLoader(val_data_list, batch_size=256, shuffle=False)
    test_loader = DataLoader(test_data_list, batch_size=256, shuffle=False)

    #Model Setup
    model = GCN(in_channels=x_tensor.shape[2], hidden_channels=64,
                mlp_hidden_channels1=32, mlp_hidden_channels2=16).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)
    loss_fn = nn.MSELoss()

    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(150):
        model.train()
        total_loss = 0
        for batch in train_loader:
            batch = batch.to(device)
            optimizer.zero_grad()
            out = model(batch)
            pred = out[batch.ba_mask]
            loss = loss_fn(pred.view(-1), batch.y.view(-1))
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_train_loss = total_loss / len(train_loader)

        # === Validation for early stopping ===
        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for val_batch in val_loader:
                val_batch = val_batch.to(device)
                out = model(val_batch)
                pred = out[val_batch.ba_mask]
                val_loss = loss_fn(pred.view(-1), val_batch.y.view(-1)).item()
                total_val_loss += val_loss
        avg_val_loss = total_val_loss / len(val_loader)
        scheduler.step(avg_val_loss)

        print(f"Epoch {epoch+1:02d} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    # === Final Validation ===
    model.load_state_dict(best_model_state)
    model.eval()
    y_pred, y_true = [], []

    with torch.no_grad():
        for test_batch in test_loader:
            test_batch = test_batch.to(device)
            out = model(test_batch)
            pred = out[test_batch.ba_mask]
            y_pred.extend(pred.cpu().view(-1).tolist())       
            y_true.extend(test_batch.y.cpu().view(-1).tolist())  

    # === Denormalize ===
    min_y = min_y_train_array[ba_index]
    max_y = max_y_train_array[ba_index]
    print(min_y, max_y)
    y_true_denorm = np.array(y_true) * (max_y - min_y) + min_y
    y_pred_denorm = np.array(y_pred) * (max_y - min_y) + min_y

    # === Compute Metrics ===
    # rms_abs = np.sqrt(mean_squared_error(y_true_denorm, y_pred_denorm))
    y_true_abs=np.mean(np.abs(y_true_denorm))
    rms_abs = np.sqrt(np.mean((y_pred_denorm - y_true_denorm) ** 2))
    rms_norm = rms_abs / np.mean(np.abs(y_true_denorm))
    mape = np.mean(np.abs(y_pred_denorm - y_true_denorm)) / np.mean(y_true_denorm)
    # mape = mean_absolute_percentage_error(y_true_denorm, y_pred_denorm)
    r2 = r2_score(y_true_denorm, y_pred_denorm)

    print(f" BA {ba_name} Validation Metrics:")
    print(f"  RMS_ABS:   {rms_abs:.4f}")
    print(f"  RMS_NORM:  {rms_norm:.4f}")
    print(f"  MAPE:      {mape:.4f}")
    print(f"  R²:        {r2:.4f}")
    print(f"  y_true_abs:        {y_true_abs:.4f}")

    # === Store ===
    results.append({
        "BA": ba_name,
        "RMS_ABS": rms_abs,
        "RMS_NORM": rms_norm,
        "MAPE": mape,
        "R2": r2,
        "y_true_abs": y_true_abs
    })

# === Save All Results ===
results_df = pd.DataFrame(results)
results_df.to_csv("validation_results_per_ba.csv", index=False)
print("All BA validation metrics saved to 'validation_results_per_ba.csv'")
# Out:
# Training for BA: AVA
# Epoch 01 | Train Loss: 0.0168 | Val Loss: 0.0062
# Epoch 02 | Train Loss: 0.0049 | Val Loss: 0.0051
# Epoch 03 | Train Loss: 0.0034 | Val Loss: 0.0037
# Epoch 04 | Train Loss: 0.0030 | Val Loss: 0.0035
# Epoch 05 | Train Loss: 0.0025 | Val Loss: 0.0023
# Epoch 06 | Train Loss: 0.0024 | Val Loss: 0.0023
# Epoch 07 | Train Loss: 0.0021 | Val Loss: 0.0028
# Epoch 08 | Train Loss: 0.0022 | Val Loss: 0.0020
# Epoch 09 | Train Loss: 0.0021 | Val Loss: 0.0024
# Epoch 10 | Train Loss: 0.0021 | Val Loss: 0.0019
# Epoch 11 | Train Loss: 0.0021 | Val Loss: 0.0019
# Epoch 12 | Train Loss: 0.0021 | Val Loss: 0.0022
# Epoch 13 | Train Loss: 0.0020 | Val Loss: 0.0025
# Epoch 14 | Train Loss: 0.0018 | Val Loss: 0.0024
# Epoch 15 | Train Loss: 0.0019 | Val Loss: 0.0020
# Epoch 16 | Train Loss: 0.0019 | Val Loss: 0.0019
# Epoch 17 | Train Loss: 0.0017 | Val Loss: 0.0017
# Epoch 18 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 19 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 20 | Train Loss: 0.0017 | Val Loss: 0.0016
# Epoch 21 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 22 | Train Loss: 0.0016 | Val Loss: 0.0019
# Epoch 23 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 24 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 25 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 26 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 27 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 28 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 29 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 30 | Train Loss: 0.0015 | Val Loss: 0.0017
# Epoch 31 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 32 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 33 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 34 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 35 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 36 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 37 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 38 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 39 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 40 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 41 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 42 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 43 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 44 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 45 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 46 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 47 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 48 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 49 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 50 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 51 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 52 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 53 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 54 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 55 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 56 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 57 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 58 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 59 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 60 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 61 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 62 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 63 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 64 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 65 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 66 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 67 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 68 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 69 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 70 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 71 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 72 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 73 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 74 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 75 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 76 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 77 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 78 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 79 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 80 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 81 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 82 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 83 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 84 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 85 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 86 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 87 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 88 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 89 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 90 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 91 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 92 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 93 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 94 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 95 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 96 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 97 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 98 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 99 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 100 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 101 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 102 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 103 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 104 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 105 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 106 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 107 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 108 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 109 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 110 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 111 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 112 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 113 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 114 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 115 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 116 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 117 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 118 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 119 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 120 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 121 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 122 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 123 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 124 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 125 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 126 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 127 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 128 | Train Loss: 0.0012 | Val Loss: 0.0014
# Early stopping at epoch 128
# 748.0 2346.0
#  BA AVA Validation Metrics:
#   RMS_ABS:   149.7680
#   RMS_NORM:  0.1021
#   MAPE:      0.0837
#   R²:        0.5995
#   y_true_abs:        1466.8343
# Training for BA: AZPS
# Epoch 01 | Train Loss: 0.0124 | Val Loss: 0.0035
# Epoch 02 | Train Loss: 0.0031 | Val Loss: 0.0033
# Epoch 03 | Train Loss: 0.0026 | Val Loss: 0.0023
# Epoch 04 | Train Loss: 0.0022 | Val Loss: 0.0027
# Epoch 05 | Train Loss: 0.0019 | Val Loss: 0.0021
# Epoch 06 | Train Loss: 0.0018 | Val Loss: 0.0016
# Epoch 07 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 08 | Train Loss: 0.0016 | Val Loss: 0.0034
# Epoch 09 | Train Loss: 0.0014 | Val Loss: 0.0016
# Epoch 10 | Train Loss: 0.0013 | Val Loss: 0.0035
# Epoch 11 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 12 | Train Loss: 0.0013 | Val Loss: 0.0012
# Epoch 13 | Train Loss: 0.0014 | Val Loss: 0.0019
# Epoch 14 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 15 | Train Loss: 0.0011 | Val Loss: 0.0018
# Epoch 16 | Train Loss: 0.0013 | Val Loss: 0.0011
# Epoch 17 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 18 | Train Loss: 0.0011 | Val Loss: 0.0013
# Epoch 19 | Train Loss: 0.0013 | Val Loss: 0.0011
# Epoch 20 | Train Loss: 0.0013 | Val Loss: 0.0013
# Epoch 21 | Train Loss: 0.0011 | Val Loss: 0.0010
# Epoch 22 | Train Loss: 0.0012 | Val Loss: 0.0011
# Epoch 23 | Train Loss: 0.0011 | Val Loss: 0.0011
# Epoch 24 | Train Loss: 0.0011 | Val Loss: 0.0010
# Epoch 25 | Train Loss: 0.0012 | Val Loss: 0.0011
# Epoch 26 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 27 | Train Loss: 0.0012 | Val Loss: 0.0011
# Epoch 28 | Train Loss: 0.0011 | Val Loss: 0.0011
# Epoch 29 | Train Loss: 0.0011 | Val Loss: 0.0010
# Epoch 30 | Train Loss: 0.0011 | Val Loss: 0.0010
# Epoch 31 | Train Loss: 0.0011 | Val Loss: 0.0011
# Epoch 32 | Train Loss: 0.0011 | Val Loss: 0.0011
# Epoch 33 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 34 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 35 | Train Loss: 0.0011 | Val Loss: 0.0010
# Epoch 36 | Train Loss: 0.0011 | Val Loss: 0.0013
# Epoch 37 | Train Loss: 0.0009 | Val Loss: 0.0009
# Epoch 38 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 39 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 40 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 41 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 42 | Train Loss: 0.0009 | Val Loss: 0.0009
# Epoch 43 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 44 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 45 | Train Loss: 0.0009 | Val Loss: 0.0012
# Epoch 46 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 47 | Train Loss: 0.0009 | Val Loss: 0.0009
# Epoch 48 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 49 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 50 | Train Loss: 0.0009 | Val Loss: 0.0009
# Epoch 51 | Train Loss: 0.0009 | Val Loss: 0.0009
# Epoch 52 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 53 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 54 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 55 | Train Loss: 0.0009 | Val Loss: 0.0009
# Epoch 56 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 57 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 58 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 59 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 60 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 61 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 62 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 63 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 64 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 65 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 66 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 67 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 68 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 69 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 70 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 71 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 72 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 73 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 74 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 75 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 76 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 77 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 78 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 79 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 80 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 81 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 82 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 83 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 84 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 85 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 86 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 87 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 88 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 89 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 90 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 91 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 92 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 93 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 94 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 95 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 96 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 97 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 98 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 99 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 100 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 101 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 102 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 103 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 104 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 105 | Train Loss: 0.0008 | Val Loss: 0.0009
# Early stopping at epoch 105
# 2028.0 7558.0
#  BA AZPS Validation Metrics:
#   RMS_ABS:   239.6061
#   RMS_NORM:  0.0702
#   MAPE:      0.0502
#   R²:        0.9464
#   y_true_abs:        3412.5911
# Training for BA: BANC
# Epoch 01 | Train Loss: 0.0069 | Val Loss: 0.0027
# Epoch 02 | Train Loss: 0.0021 | Val Loss: 0.0022
# Epoch 03 | Train Loss: 0.0014 | Val Loss: 0.0020
# Epoch 04 | Train Loss: 0.0015 | Val Loss: 0.0011
# Epoch 05 | Train Loss: 0.0011 | Val Loss: 0.0015
# Epoch 06 | Train Loss: 0.0011 | Val Loss: 0.0008
# Epoch 07 | Train Loss: 0.0009 | Val Loss: 0.0009
# Epoch 08 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 09 | Train Loss: 0.0009 | Val Loss: 0.0008
# Epoch 10 | Train Loss: 0.0008 | Val Loss: 0.0012
# Epoch 11 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 12 | Train Loss: 0.0008 | Val Loss: 0.0012
# Epoch 13 | Train Loss: 0.0009 | Val Loss: 0.0008
# Epoch 14 | Train Loss: 0.0007 | Val Loss: 0.0007
# Epoch 15 | Train Loss: 0.0007 | Val Loss: 0.0006
# Epoch 16 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 17 | Train Loss: 0.0007 | Val Loss: 0.0007
# Epoch 18 | Train Loss: 0.0008 | Val Loss: 0.0006
# Epoch 19 | Train Loss: 0.0008 | Val Loss: 0.0006
# Epoch 20 | Train Loss: 0.0006 | Val Loss: 0.0006
# Epoch 21 | Train Loss: 0.0006 | Val Loss: 0.0006
# Epoch 22 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 23 | Train Loss: 0.0006 | Val Loss: 0.0009
# Epoch 24 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 25 | Train Loss: 0.0007 | Val Loss: 0.0007
# Epoch 26 | Train Loss: 0.0007 | Val Loss: 0.0006
# Epoch 27 | Train Loss: 0.0006 | Val Loss: 0.0005
# Epoch 28 | Train Loss: 0.0006 | Val Loss: 0.0005
# Epoch 29 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 30 | Train Loss: 0.0007 | Val Loss: 0.0007
# Epoch 31 | Train Loss: 0.0006 | Val Loss: 0.0006
# Epoch 32 | Train Loss: 0.0006 | Val Loss: 0.0005
# Epoch 33 | Train Loss: 0.0006 | Val Loss: 0.0014
# Epoch 34 | Train Loss: 0.0006 | Val Loss: 0.0005
# Epoch 35 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 36 | Train Loss: 0.0006 | Val Loss: 0.0005
# Epoch 37 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 38 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 39 | Train Loss: 0.0006 | Val Loss: 0.0005
# Epoch 40 | Train Loss: 0.0005 | Val Loss: 0.0007
# Epoch 41 | Train Loss: 0.0005 | Val Loss: 0.0010
# Epoch 42 | Train Loss: 0.0007 | Val Loss: 0.0006
# Epoch 43 | Train Loss: 0.0006 | Val Loss: 0.0005
# Epoch 44 | Train Loss: 0.0006 | Val Loss: 0.0005
# Epoch 45 | Train Loss: 0.0006 | Val Loss: 0.0005
# Epoch 46 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 47 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 48 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 49 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 50 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 51 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 52 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 53 | Train Loss: 0.0005 | Val Loss: 0.0004
# Epoch 54 | Train Loss: 0.0004 | Val Loss: 0.0005
# Epoch 55 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 56 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 57 | Train Loss: 0.0005 | Val Loss: 0.0004
# Epoch 58 | Train Loss: 0.0005 | Val Loss: 0.0005
# Epoch 59 | Train Loss: 0.0004 | Val Loss: 0.0005
# Epoch 60 | Train Loss: 0.0004 | Val Loss: 0.0005
# Epoch 61 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 62 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 63 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 64 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 65 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 66 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 67 | Train Loss: 0.0004 | Val Loss: 0.0005
# Epoch 68 | Train Loss: 0.0004 | Val Loss: 0.0005
# Epoch 69 | Train Loss: 0.0004 | Val Loss: 0.0005
# Epoch 70 | Train Loss: 0.0004 | Val Loss: 0.0005
# Epoch 71 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 72 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 73 | Train Loss: 0.0004 | Val Loss: 0.0005
# Epoch 74 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 75 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 76 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 77 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 78 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 79 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 80 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 81 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 82 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 83 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 84 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 85 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 86 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 87 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 88 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 89 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 90 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 91 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 92 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 93 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 94 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 95 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 96 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 97 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 98 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 99 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 100 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 101 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 102 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 103 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 104 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 105 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 106 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 107 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 108 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 109 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 110 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 111 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 112 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 113 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 114 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 115 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 116 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 117 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 118 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 119 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 120 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 121 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 122 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 123 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 124 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 125 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 126 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 127 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 128 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 129 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 130 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 131 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 132 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 133 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 134 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 135 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 136 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 137 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 138 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 139 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 140 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 141 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 142 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 143 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 144 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 145 | Train Loss: 0.0004 | Val Loss: 0.0004
# Epoch 146 | Train Loss: 0.0004 | Val Loss: 0.0004
# Early stopping at epoch 146
# 0.0 4763.0
#  BA BANC Validation Metrics:
#   RMS_ABS:   130.9408
#   RMS_NORM:  0.0669
#   MAPE:      0.0488
#   R²:        0.9378
#   y_true_abs:        1958.6031
# Training for BA: BPAT
# Epoch 01 | Train Loss: 0.0070 | Val Loss: 0.0044
# Epoch 02 | Train Loss: 0.0026 | Val Loss: 0.0033
# Epoch 03 | Train Loss: 0.0019 | Val Loss: 0.0016
# Epoch 04 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 05 | Train Loss: 0.0013 | Val Loss: 0.0013
# Epoch 06 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 07 | Train Loss: 0.0011 | Val Loss: 0.0013
# Epoch 08 | Train Loss: 0.0011 | Val Loss: 0.0011
# Epoch 09 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 10 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 11 | Train Loss: 0.0010 | Val Loss: 0.0013
# Epoch 12 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 13 | Train Loss: 0.0010 | Val Loss: 0.0013
# Epoch 14 | Train Loss: 0.0010 | Val Loss: 0.0010
# Epoch 15 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 16 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 17 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 18 | Train Loss: 0.0009 | Val Loss: 0.0014
# Epoch 19 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 20 | Train Loss: 0.0009 | Val Loss: 0.0014
# Epoch 21 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 22 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 23 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 24 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 25 | Train Loss: 0.0007 | Val Loss: 0.0009
# Epoch 26 | Train Loss: 0.0008 | Val Loss: 0.0008
# Epoch 27 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 28 | Train Loss: 0.0008 | Val Loss: 0.0008
# Epoch 29 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 30 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 31 | Train Loss: 0.0007 | Val Loss: 0.0009
# Epoch 32 | Train Loss: 0.0007 | Val Loss: 0.0009
# Epoch 33 | Train Loss: 0.0008 | Val Loss: 0.0009
# Epoch 34 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 35 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 36 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 37 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 38 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 39 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 40 | Train Loss: 0.0007 | Val Loss: 0.0009
# Epoch 41 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 42 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 43 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 44 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 45 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 46 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 47 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 48 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 49 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 50 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 51 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 52 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 53 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 54 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 55 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 56 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 57 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 58 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 59 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 60 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 61 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 62 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 63 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 64 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 65 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 66 | Train Loss: 0.0007 | Val Loss: 0.0008
# Epoch 67 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 68 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 69 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 70 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 71 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 72 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 73 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 74 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 75 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 76 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 77 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 78 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 79 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 80 | Train Loss: 0.0006 | Val Loss: 0.0008
# Epoch 81 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 82 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 83 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 84 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 85 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 86 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 87 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 88 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 89 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 90 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 91 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 92 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 93 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 94 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 95 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 96 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 97 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 98 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 99 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 100 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 101 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 102 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 103 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 104 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 105 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 106 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 107 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 108 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 109 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 110 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 111 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 112 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 113 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 114 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 115 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 116 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 117 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 118 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 119 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 120 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 121 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 122 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 123 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 124 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 125 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 126 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 127 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 128 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 129 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 130 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 131 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 132 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 133 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 134 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 135 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 136 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 137 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 138 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 139 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 140 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 141 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 142 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 143 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 144 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 145 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 146 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 147 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 148 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 149 | Train Loss: 0.0006 | Val Loss: 0.0007
# Epoch 150 | Train Loss: 0.0006 | Val Loss: 0.0007
# 3659.0 11827.0
#  BA BPAT Validation Metrics:
#   RMS_ABS:   247.6605
#   RMS_NORM:  0.0390
#   MAPE:      0.0297
#   R²:        0.9348
#   y_true_abs:        6345.6050
# Training for BA: CHPD
# Epoch 01 | Train Loss: 0.0161 | Val Loss: 0.0045
# Epoch 02 | Train Loss: 0.0034 | Val Loss: 0.0029
# Epoch 03 | Train Loss: 0.0025 | Val Loss: 0.0024
# Epoch 04 | Train Loss: 0.0022 | Val Loss: 0.0024
# Epoch 05 | Train Loss: 0.0020 | Val Loss: 0.0022
# Epoch 06 | Train Loss: 0.0018 | Val Loss: 0.0024
# Epoch 07 | Train Loss: 0.0020 | Val Loss: 0.0018
# Epoch 08 | Train Loss: 0.0017 | Val Loss: 0.0021
# Epoch 09 | Train Loss: 0.0017 | Val Loss: 0.0017
# Epoch 10 | Train Loss: 0.0015 | Val Loss: 0.0020
# Epoch 11 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 12 | Train Loss: 0.0015 | Val Loss: 0.0017
# Epoch 13 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 14 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 15 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 16 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 17 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 18 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 19 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 20 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 21 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 22 | Train Loss: 0.0013 | Val Loss: 0.0013
# Epoch 23 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 24 | Train Loss: 0.0013 | Val Loss: 0.0016
# Epoch 25 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 26 | Train Loss: 0.0013 | Val Loss: 0.0013
# Epoch 27 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 28 | Train Loss: 0.0013 | Val Loss: 0.0013
# Epoch 29 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 30 | Train Loss: 0.0012 | Val Loss: 0.0015
# Epoch 31 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 32 | Train Loss: 0.0012 | Val Loss: 0.0015
# Epoch 33 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 34 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 35 | Train Loss: 0.0011 | Val Loss: 0.0016
# Epoch 36 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 37 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 38 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 39 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 40 | Train Loss: 0.0012 | Val Loss: 0.0015
# Epoch 41 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 42 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 43 | Train Loss: 0.0011 | Val Loss: 0.0013
# Epoch 44 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 45 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 46 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 47 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 48 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 49 | Train Loss: 0.0010 | Val Loss: 0.0013
# Epoch 50 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 51 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 52 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 53 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 54 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 55 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 56 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 57 | Train Loss: 0.0010 | Val Loss: 0.0013
# Epoch 58 | Train Loss: 0.0010 | Val Loss: 0.0013
# Epoch 59 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 60 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 61 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 62 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 63 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 64 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 65 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 66 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 67 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 68 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 69 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 70 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 71 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 72 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 73 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 74 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 75 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 76 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 77 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 78 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 79 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 80 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 81 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 82 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 83 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 84 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 85 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 86 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 87 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 88 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 89 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 90 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 91 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 92 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 93 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 94 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 95 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 96 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 97 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 98 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 99 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 100 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 101 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 102 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 103 | Train Loss: 0.0009 | Val Loss: 0.0011
# Epoch 104 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 105 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 106 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 107 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 108 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 109 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 110 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 111 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 112 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 113 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 114 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 115 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 116 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 117 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 118 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 119 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 120 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 121 | Train Loss: 0.0009 | Val Loss: 0.0010
# Epoch 122 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 123 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 124 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 125 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 126 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 127 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 128 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 129 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 130 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 131 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 132 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 133 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 134 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 135 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 136 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 137 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 138 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 139 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 140 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 141 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 142 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 143 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 144 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 145 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 146 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 147 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 148 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 149 | Train Loss: 0.0008 | Val Loss: 0.0010
# Epoch 150 | Train Loss: 0.0008 | Val Loss: 0.0010
# 27.0 494.0
#  BA CHPD Validation Metrics:
#   RMS_ABS:   24.7391
#   RMS_NORM:  0.1191
#   MAPE:      0.0679
#   R²:        0.8713
#   y_true_abs:        207.7106
# Training for BA: CISO
# Epoch 01 | Train Loss: 0.0121 | Val Loss: 0.0055
# Epoch 02 | Train Loss: 0.0043 | Val Loss: 0.0036
# Epoch 03 | Train Loss: 0.0027 | Val Loss: 0.0037
# Epoch 04 | Train Loss: 0.0025 | Val Loss: 0.0022
# Epoch 05 | Train Loss: 0.0024 | Val Loss: 0.0024
# Epoch 06 | Train Loss: 0.0021 | Val Loss: 0.0022
# Epoch 07 | Train Loss: 0.0021 | Val Loss: 0.0018
# Epoch 08 | Train Loss: 0.0019 | Val Loss: 0.0018
# Epoch 09 | Train Loss: 0.0019 | Val Loss: 0.0018
# Epoch 10 | Train Loss: 0.0021 | Val Loss: 0.0025
# Epoch 11 | Train Loss: 0.0019 | Val Loss: 0.0021
# Epoch 12 | Train Loss: 0.0018 | Val Loss: 0.0017
# Epoch 13 | Train Loss: 0.0018 | Val Loss: 0.0016
# Epoch 14 | Train Loss: 0.0017 | Val Loss: 0.0026
# Epoch 15 | Train Loss: 0.0018 | Val Loss: 0.0016
# Epoch 16 | Train Loss: 0.0017 | Val Loss: 0.0016
# Epoch 17 | Train Loss: 0.0019 | Val Loss: 0.0018
# Epoch 18 | Train Loss: 0.0018 | Val Loss: 0.0018
# Epoch 19 | Train Loss: 0.0018 | Val Loss: 0.0017
# Epoch 20 | Train Loss: 0.0016 | Val Loss: 0.0015
# Epoch 21 | Train Loss: 0.0015 | Val Loss: 0.0017
# Epoch 22 | Train Loss: 0.0016 | Val Loss: 0.0015
# Epoch 23 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 24 | Train Loss: 0.0016 | Val Loss: 0.0015
# Epoch 25 | Train Loss: 0.0016 | Val Loss: 0.0018
# Epoch 26 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 27 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 28 | Train Loss: 0.0015 | Val Loss: 0.0021
# Epoch 29 | Train Loss: 0.0016 | Val Loss: 0.0017
# Epoch 30 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 31 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 32 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 33 | Train Loss: 0.0014 | Val Loss: 0.0016
# Epoch 34 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 35 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 36 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 37 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 38 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 39 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 40 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 41 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 42 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 43 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 44 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 45 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 46 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 47 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 48 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 49 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 50 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 51 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 52 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 53 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 54 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 55 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 56 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 57 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 58 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 59 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 60 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 61 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 62 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 63 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 64 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 65 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 66 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 67 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 68 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 69 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 70 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 71 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 72 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 73 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 74 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 75 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 76 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 77 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 78 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 79 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 80 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 81 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 82 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 83 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 84 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 85 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 86 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 87 | Train Loss: 0.0013 | Val Loss: 0.0014
# Early stopping at epoch 87
# 18068.0 49899.0
#  BA CISO Validation Metrics:
#   RMS_ABS:   2370.1937
#   RMS_NORM:  0.0964
#   MAPE:      0.0713
#   R²:        0.7659
#   y_true_abs:        24589.4467
# Training for BA: DOPD
# Epoch 01 | Train Loss: 0.0197 | Val Loss: 0.0049
# Epoch 02 | Train Loss: 0.0039 | Val Loss: 0.0043
# Epoch 03 | Train Loss: 0.0028 | Val Loss: 0.0026
# Epoch 04 | Train Loss: 0.0024 | Val Loss: 0.0023
# Epoch 05 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 06 | Train Loss: 0.0020 | Val Loss: 0.0030
# Epoch 07 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 08 | Train Loss: 0.0018 | Val Loss: 0.0019
# Epoch 09 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 10 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 11 | Train Loss: 0.0017 | Val Loss: 0.0017
# Epoch 12 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 13 | Train Loss: 0.0016 | Val Loss: 0.0018
# Epoch 14 | Train Loss: 0.0016 | Val Loss: 0.0017
# Epoch 15 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 16 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 17 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 18 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 19 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 20 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 21 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 22 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 23 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 24 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 25 | Train Loss: 0.0014 | Val Loss: 0.0013
# Epoch 26 | Train Loss: 0.0013 | Val Loss: 0.0016
# Epoch 27 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 28 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 29 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 30 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 31 | Train Loss: 0.0014 | Val Loss: 0.0013
# Epoch 32 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 33 | Train Loss: 0.0014 | Val Loss: 0.0016
# Epoch 34 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 35 | Train Loss: 0.0014 | Val Loss: 0.0013
# Epoch 36 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 37 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 38 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 39 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 40 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 41 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 42 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 43 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 44 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 45 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 46 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 47 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 48 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 49 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 50 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 51 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 52 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 53 | Train Loss: 0.0012 | Val Loss: 0.0014
# Epoch 54 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 55 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 56 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 57 | Train Loss: 0.0012 | Val Loss: 0.0012
# Epoch 58 | Train Loss: 0.0012 | Val Loss: 0.0013
# Epoch 59 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 60 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 61 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 62 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 63 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 64 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 65 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 66 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 67 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 68 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 69 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 70 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 71 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 72 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 73 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 74 | Train Loss: 0.0011 | Val Loss: 0.0013
# Epoch 75 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 76 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 77 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 78 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 79 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 80 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 81 | Train Loss: 0.0011 | Val Loss: 0.0012
# Epoch 82 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 83 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 84 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 85 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 86 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 87 | Train Loss: 0.0010 | Val Loss: 0.0012
# Epoch 88 | Train Loss: 0.0011 | Val Loss: 0.0011
# Epoch 89 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 90 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 91 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 92 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 93 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 94 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 95 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 96 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 97 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 98 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 99 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 100 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 101 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 102 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 103 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 104 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 105 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 106 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 107 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 108 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 109 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 110 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 111 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 112 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 113 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 114 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 115 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 116 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 117 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 118 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 119 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 120 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 121 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 122 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 123 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 124 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 125 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 126 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 127 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 128 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 129 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 130 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 131 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 132 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 133 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 134 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 135 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 136 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 137 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 138 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 139 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 140 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 141 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 142 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 143 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 144 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 145 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 146 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 147 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 148 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 149 | Train Loss: 0.0010 | Val Loss: 0.0011
# Epoch 150 | Train Loss: 0.0010 | Val Loss: 0.0011
# 0.0 397.0
#  BA DOPD Validation Metrics:
#   RMS_ABS:   30.1838
#   RMS_NORM:  0.1472
#   MAPE:      0.1305
#   R²:        0.5234
#   y_true_abs:        205.0481
# Training for BA: EPE
# Epoch 01 | Train Loss: 0.0291 | Val Loss: 0.0052
# Epoch 02 | Train Loss: 0.0039 | Val Loss: 0.0030
# Epoch 03 | Train Loss: 0.0025 | Val Loss: 0.0024
# Epoch 04 | Train Loss: 0.0020 | Val Loss: 0.0019
# Epoch 05 | Train Loss: 0.0020 | Val Loss: 0.0019
# Epoch 06 | Train Loss: 0.0019 | Val Loss: 0.0018
# Epoch 07 | Train Loss: 0.0017 | Val Loss: 0.0019
# Epoch 08 | Train Loss: 0.0017 | Val Loss: 0.0016
# Epoch 09 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 10 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 11 | Train Loss: 0.0016 | Val Loss: 0.0014
# Epoch 12 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 13 | Train Loss: 0.0016 | Val Loss: 0.0014
# Epoch 14 | Train Loss: 0.0015 | Val Loss: 0.0017
# Epoch 15 | Train Loss: 0.0015 | Val Loss: 0.0013
# Epoch 16 | Train Loss: 0.0015 | Val Loss: 0.0013
# Epoch 17 | Train Loss: 0.0015 | Val Loss: 0.0018
# Epoch 18 | Train Loss: 0.0015 | Val Loss: 0.0014
# Epoch 19 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 20 | Train Loss: 0.0015 | Val Loss: 0.0013
# Epoch 21 | Train Loss: 0.0014 | Val Loss: 0.0013
# Epoch 22 | Train Loss: 0.0014 | Val Loss: 0.0012
# Epoch 23 | Train Loss: 0.0014 | Val Loss: 0.0018
# Epoch 24 | Train Loss: 0.0014 | Val Loss: 0.0013
# Epoch 25 | Train Loss: 0.0014 | Val Loss: 0.0012
# Epoch 26 | Train Loss: 0.0014 | Val Loss: 0.0013
# Epoch 27 | Train Loss: 0.0013 | Val Loss: 0.0016
# Epoch 28 | Train Loss: 0.0014 | Val Loss: 0.0012
# Epoch 29 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 30 | Train Loss: 0.0015 | Val Loss: 0.0015
# ...
# Epoch 139 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 140 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 141 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 142 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 143 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 144 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 145 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 146 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 147 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 148 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 149 | Train Loss: 0.0007 | Val Loss: 0.0010
# Epoch 150 | Train Loss: 0.0007 | Val Loss: 0.0010
# 0.0 5774.0
#  BA WACM Validation Metrics:
#   RMS_ABS:   494.8917
#   RMS_NORM:  0.1925
#   MAPE:      0.1638
#   R²:        -0.3668
#   y_true_abs:        2571.4485
# Training for BA: WALC
# Epoch 01 | Train Loss: 0.0068 | Val Loss: 0.0036
# Epoch 02 | Train Loss: 0.0032 | Val Loss: 0.0029
# Epoch 03 | Train Loss: 0.0027 | Val Loss: 0.0026
# Epoch 04 | Train Loss: 0.0025 | Val Loss: 0.0025
# Epoch 05 | Train Loss: 0.0025 | Val Loss: 0.0026
# Epoch 06 | Train Loss: 0.0025 | Val Loss: 0.0024
# Epoch 07 | Train Loss: 0.0025 | Val Loss: 0.0024
# Epoch 08 | Train Loss: 0.0024 | Val Loss: 0.0024
# Epoch 09 | Train Loss: 0.0025 | Val Loss: 0.0024
# Epoch 10 | Train Loss: 0.0024 | Val Loss: 0.0023
# Epoch 11 | Train Loss: 0.0023 | Val Loss: 0.0024
# Epoch 12 | Train Loss: 0.0023 | Val Loss: 0.0024
# Epoch 13 | Train Loss: 0.0024 | Val Loss: 0.0026
# Epoch 14 | Train Loss: 0.0023 | Val Loss: 0.0026
# Epoch 15 | Train Loss: 0.0023 | Val Loss: 0.0023
# Epoch 16 | Train Loss: 0.0023 | Val Loss: 0.0029
# Epoch 17 | Train Loss: 0.0023 | Val Loss: 0.0022
# Epoch 18 | Train Loss: 0.0022 | Val Loss: 0.0023
# Epoch 19 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 20 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 21 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 22 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 23 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 24 | Train Loss: 0.0021 | Val Loss: 0.0023
# Epoch 25 | Train Loss: 0.0021 | Val Loss: 0.0022
# Epoch 26 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 27 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 28 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 29 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 30 | Train Loss: 0.0021 | Val Loss: 0.0022
# Epoch 31 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 32 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 33 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 34 | Train Loss: 0.0021 | Val Loss: 0.0022
# Epoch 35 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 36 | Train Loss: 0.0021 | Val Loss: 0.0023
# Epoch 37 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 38 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 39 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 40 | Train Loss: 0.0020 | Val Loss: 0.0019
# Epoch 41 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 42 | Train Loss: 0.0019 | Val Loss: 0.0020
# Epoch 43 | Train Loss: 0.0019 | Val Loss: 0.0021
# Epoch 44 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 45 | Train Loss: 0.0019 | Val Loss: 0.0021
# Epoch 46 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 47 | Train Loss: 0.0018 | Val Loss: 0.0018
# Epoch 48 | Train Loss: 0.0018 | Val Loss: 0.0018
# Epoch 49 | Train Loss: 0.0018 | Val Loss: 0.0019
# Epoch 50 | Train Loss: 0.0018 | Val Loss: 0.0018
# Epoch 51 | Train Loss: 0.0018 | Val Loss: 0.0018
# Epoch 52 | Train Loss: 0.0017 | Val Loss: 0.0019
# Epoch 53 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 54 | Train Loss: 0.0017 | Val Loss: 0.0021
# Epoch 55 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 56 | Train Loss: 0.0017 | Val Loss: 0.0017
# Epoch 57 | Train Loss: 0.0017 | Val Loss: 0.0017
# Epoch 58 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 59 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 60 | Train Loss: 0.0017 | Val Loss: 0.0020
# Epoch 61 | Train Loss: 0.0017 | Val Loss: 0.0020
# Epoch 62 | Train Loss: 0.0017 | Val Loss: 0.0017
# Epoch 63 | Train Loss: 0.0017 | Val Loss: 0.0017
# Epoch 64 | Train Loss: 0.0017 | Val Loss: 0.0019
# Epoch 65 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 66 | Train Loss: 0.0017 | Val Loss: 0.0018
# Epoch 67 | Train Loss: 0.0017 | Val Loss: 0.0017
# Epoch 68 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 69 | Train Loss: 0.0016 | Val Loss: 0.0018
# Epoch 70 | Train Loss: 0.0016 | Val Loss: 0.0020
# Epoch 71 | Train Loss: 0.0017 | Val Loss: 0.0017
# Epoch 72 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 73 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 74 | Train Loss: 0.0016 | Val Loss: 0.0017
# Epoch 75 | Train Loss: 0.0016 | Val Loss: 0.0017
# Epoch 76 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 77 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 78 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 79 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 80 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 81 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 82 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 83 | Train Loss: 0.0016 | Val Loss: 0.0016
# Epoch 84 | Train Loss: 0.0016 | Val Loss: 0.0017
# Epoch 85 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 86 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 87 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 88 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 89 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 90 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 91 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 92 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 93 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 94 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 95 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 96 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 97 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 98 | Train Loss: 0.0015 | Val Loss: 0.0015
# Epoch 99 | Train Loss: 0.0014 | Val Loss: 0.0016
# Epoch 100 | Train Loss: 0.0015 | Val Loss: 0.0016
# Epoch 101 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 102 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 103 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 104 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 105 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 106 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 107 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 108 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 109 | Train Loss: 0.0014 | Val Loss: 0.0016
# Epoch 110 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 111 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 112 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 113 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 114 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 115 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 116 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 117 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 118 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 119 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 120 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 121 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 122 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 123 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 124 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 125 | Train Loss: 0.0014 | Val Loss: 0.0015
# Epoch 126 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 127 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 128 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 129 | Train Loss: 0.0014 | Val Loss: 0.0014
# Epoch 130 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 131 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 132 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 133 | Train Loss: 0.0013 | Val Loss: 0.0015
# Epoch 134 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 135 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 136 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 137 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 138 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 139 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 140 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 141 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 142 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 143 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 144 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 145 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 146 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 147 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 148 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 149 | Train Loss: 0.0013 | Val Loss: 0.0014
# Epoch 150 | Train Loss: 0.0013 | Val Loss: 0.0014
# 0.0 2299.0
#  BA WALC Validation Metrics:
#   RMS_ABS:   170.2205
#   RMS_NORM:  0.1553
#   MAPE:      0.1230
#   R²:        0.6208
#   y_true_abs:        1096.0643
# Training for BA: WAUW
# Epoch 01 | Train Loss: 0.0164 | Val Loss: 0.0078
# Epoch 02 | Train Loss: 0.0063 | Val Loss: 0.0089
# Epoch 03 | Train Loss: 0.0049 | Val Loss: 0.0041
# Epoch 04 | Train Loss: 0.0042 | Val Loss: 0.0050
# Epoch 05 | Train Loss: 0.0040 | Val Loss: 0.0040
# Epoch 06 | Train Loss: 0.0037 | Val Loss: 0.0037
# Epoch 07 | Train Loss: 0.0037 | Val Loss: 0.0033
# Epoch 08 | Train Loss: 0.0036 | Val Loss: 0.0034
# Epoch 09 | Train Loss: 0.0034 | Val Loss: 0.0030
# Epoch 10 | Train Loss: 0.0033 | Val Loss: 0.0031
# Epoch 11 | Train Loss: 0.0033 | Val Loss: 0.0029
# Epoch 12 | Train Loss: 0.0033 | Val Loss: 0.0032
# Epoch 13 | Train Loss: 0.0033 | Val Loss: 0.0028
# Epoch 14 | Train Loss: 0.0030 | Val Loss: 0.0028
# Epoch 15 | Train Loss: 0.0030 | Val Loss: 0.0026
# Epoch 16 | Train Loss: 0.0030 | Val Loss: 0.0027
# Epoch 17 | Train Loss: 0.0029 | Val Loss: 0.0031
# Epoch 18 | Train Loss: 0.0030 | Val Loss: 0.0030
# Epoch 19 | Train Loss: 0.0030 | Val Loss: 0.0025
# Epoch 20 | Train Loss: 0.0029 | Val Loss: 0.0030
# Epoch 21 | Train Loss: 0.0028 | Val Loss: 0.0025
# Epoch 22 | Train Loss: 0.0028 | Val Loss: 0.0025
# Epoch 23 | Train Loss: 0.0028 | Val Loss: 0.0029
# Epoch 24 | Train Loss: 0.0028 | Val Loss: 0.0026
# Epoch 25 | Train Loss: 0.0027 | Val Loss: 0.0026
# Epoch 26 | Train Loss: 0.0027 | Val Loss: 0.0025
# Epoch 27 | Train Loss: 0.0028 | Val Loss: 0.0047
# Epoch 28 | Train Loss: 0.0029 | Val Loss: 0.0023
# Epoch 29 | Train Loss: 0.0025 | Val Loss: 0.0023
# Epoch 30 | Train Loss: 0.0024 | Val Loss: 0.0024
# Epoch 31 | Train Loss: 0.0024 | Val Loss: 0.0025
# Epoch 32 | Train Loss: 0.0025 | Val Loss: 0.0023
# Epoch 33 | Train Loss: 0.0025 | Val Loss: 0.0023
# Epoch 34 | Train Loss: 0.0024 | Val Loss: 0.0024
# Epoch 35 | Train Loss: 0.0024 | Val Loss: 0.0023
# Epoch 36 | Train Loss: 0.0024 | Val Loss: 0.0022
# Epoch 37 | Train Loss: 0.0024 | Val Loss: 0.0023
# Epoch 38 | Train Loss: 0.0023 | Val Loss: 0.0022
# Epoch 39 | Train Loss: 0.0024 | Val Loss: 0.0022
# Epoch 40 | Train Loss: 0.0023 | Val Loss: 0.0022
# Epoch 41 | Train Loss: 0.0023 | Val Loss: 0.0024
# Epoch 42 | Train Loss: 0.0023 | Val Loss: 0.0022
# Epoch 43 | Train Loss: 0.0023 | Val Loss: 0.0022
# Epoch 44 | Train Loss: 0.0023 | Val Loss: 0.0022
# Epoch 45 | Train Loss: 0.0023 | Val Loss: 0.0022
# Epoch 46 | Train Loss: 0.0023 | Val Loss: 0.0022
# Epoch 47 | Train Loss: 0.0023 | Val Loss: 0.0022
# Epoch 48 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 49 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 50 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 51 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 52 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 53 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 54 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 55 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 56 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 57 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 58 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 59 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 60 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 61 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 62 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 63 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 64 | Train Loss: 0.0022 | Val Loss: 0.0023
# Epoch 65 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 66 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 67 | Train Loss: 0.0022 | Val Loss: 0.0021
# Epoch 68 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 69 | Train Loss: 0.0022 | Val Loss: 0.0022
# Epoch 70 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 71 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 72 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 73 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 74 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 75 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 76 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 77 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 78 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 79 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 80 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 81 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 82 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 83 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 84 | Train Loss: 0.0021 | Val Loss: 0.0021
# Epoch 85 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 86 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 87 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 88 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 89 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 90 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 91 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 92 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 93 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 94 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 95 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 96 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 97 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 98 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 99 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 100 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 101 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 102 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 103 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 104 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 105 | Train Loss: 0.0021 | Val Loss: 0.0020
# Epoch 106 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 107 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 108 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 109 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 110 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 111 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 112 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 113 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 114 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 115 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 116 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 117 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 118 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 119 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 120 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 121 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 122 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 123 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 124 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 125 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 126 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 127 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 128 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 129 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 130 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 131 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 132 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 133 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 134 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 135 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 136 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 137 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 138 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 139 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 140 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 141 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 142 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 143 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 144 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 145 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 146 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 147 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 148 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 149 | Train Loss: 0.0020 | Val Loss: 0.0020
# Epoch 150 | Train Loss: 0.0020 | Val Loss: 0.0020
# 5.0 168.0
#  BA WAUW Validation Metrics:
#   RMS_ABS:   9.0982
#   RMS_NORM:  0.0971
#   MAPE:      0.0743
#   R²:        0.7343
#   y_true_abs:        93.6634
# All BA validation metrics saved to 'validation_results_per_ba.csv'
